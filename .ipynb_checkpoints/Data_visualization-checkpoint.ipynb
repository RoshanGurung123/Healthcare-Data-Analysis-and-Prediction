# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('diabetic_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
# Since the empty data in the data set are '?' value replacing the ? value with NAn 
df.replace('?', np.nan, inplace=True)

# %%
# Check for null values in the entire DataFrame
null_values = df.isnull()

# Count the number of null values in each column
null_count = df.isnull().sum()

# Display the null count for each column
print(null_count)
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
# new_df.columns

# %%
# len(new_df.columns)

# %%
# new_df['weight']

# %%
# new_df=new_df.drop('weight', axis=1)
# new_df

# %%
# new_df['payer_code'].value_counts()

# %%
# new_df=new_df.drop('payer_code', axis=1)
# new_df

# %%
# missing_data=new_df.isna()
# missing_data

# %%
# # Check if any missing data exists
# any_missing = missing_data.any().any()

# # Check the total count of missing values
# total_missing_count = missing_data.sum().sum()

# print("Are there any missing values?", any_missing)
# print("Total missing values:", total_missing_count)

# %%
# new_df['medical_specialty'].value_counts()

# %%
# new_df=new_df.drop('medical_specialty', axis=1)
# new_df

# %%
# len(new_df)

# %%
# randomly selecting 10000 data from the cleaned dataset
sample_size=10000
new_sample_df=df.sample(n=sample_size)

# %%
len(new_sample_df)
# Out:
# 10000

# %%
new_sample_df.to_csv('final_diabetic_dataset_1.csv', index=False)

# %%
final_df=pd.read_csv('final_diabetic_dataset.csv')
final_df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0     258928482     33378192        Caucasian  Female  [50-60)
# 1     151650456    111717297        Caucasian  Female  [70-80)
# 2     144146046     92052630        Caucasian  Female  [70-80)
# 3     171419850     65184075  AfricanAmerican  Female  [50-60)
# 4     158934780     26147637        Caucasian  Female  [50-60)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         1                    7
# 1                  2                        22                    7
# 2                  2                         3                    7
# 3                  1                         3                    7
# 4                  2                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  citoglipton  insulin  \
# 0                 8                  56  ...           No       Up
# ...

# %%
len(final_df.columns)
# Out:
# 47
